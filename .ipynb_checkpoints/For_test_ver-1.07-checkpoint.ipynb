# %%
import torch
import random
import torchvision
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.nn.functional as F
import argparse,os,time
import os
import time
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy
from scipy.io import wavfile
from glob import glob
from tqdm import tqdm
from sklearn.model_selection import train_test_split
import seaborn as sns
import librosa
import librosa.display
import torchaudio
import torchaudio.transforms as AT

# %%
data = pd.read_csv('test.csv', index_col=0)

# %%
data
# Out:
#       letter  0  1  2  3  4  5  6  7  8  ...  774  775  776  777  778  779  \
# id                                       ...
# 2049       L  0  4  0  2  4  2  3  1  0  ...    2    0    4    2    2    4
# 2050       C  4  1  4  0  1  1  0  2  2  ...    0    3    2    4    2    4
# 2051       S  0  4  0  1  3  2  3  0  2  ...    1    3    2    0    3    2
# 2052       K  2  1  3  3  3  4  3  0  0  ...    3    0    3    2    4    1
# 2053       W  1  0  1  1  2  2  1  4  1  ...    4    3    1    4    0    2
# ...      ... .. .. .. .. .. .. .. .. ..  ...  ...  ...  ...  ...  ...  ...
# 22524      P  1  2  1  1  0  0  0  2  1  ...    0    1    3    0    3    0
# 22525      S  4  1  1  4  0  0  1  1  4  ...    1    3    1    0    0    1
# 22526      B  4  2  1  3  2  1  3  0  4  ...    3    2    3    4    1    0
# 22527      K  1  1  2  3  4  0  4  3  1  ...    2    0    0    4    3    3
# 22528      S  2  1  0  3  0  3  3  1  0  ...    0    3    0    1    4    2
#
#        780  781  782  783
# id
# 2049     3    4    1    4
# 2050     2    2    1    2
# 2051     3    0    1    4
# 2052     0    4    4    4
# 2053     1    2    3    4
# ...    ...  ...  ...  ...
# 22524    4    3    1    4
# 22525    3    1    2    0
# 22526    3    3    1    1
# 22527    3    4    4    2
# 22528    0    2    2    0
#
# [20480 rows x 785 columns]

# %%
x_data=data.loc[:,"0":"783"].values

# %%
x_data=x_data.astype(np.float32)

# %%
x_data_test=x_data

# %%
x_data_test=x_data_test/x_data_test.max()

# %%
x_data=x_data_test.astype(np.float32)

# %%
batch_size=1

# %%
class Model(torch.nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.layer_1 = nn.Conv2d(in_channels=1,out_channels=128,kernel_size=3,
                                 stride=1,padding=2)
        self.act_1 = nn.ReLU()
        
        self.layer_2 = nn.Conv2d(in_channels=128,out_channels=128,kernel_size=3,
                                 stride=1,padding=2)
        self.act_2 = nn.ReLU()
        
        self.layer_3 = nn.Conv2d(in_channels=128,out_channels=128,kernel_size=3,
                                 stride=1,padding=2)
        self.act_3 = nn.ReLU()
        
        self.layer_4 = nn.Conv2d(in_channels=128,out_channels=128,kernel_size=3,
                                 stride=1,padding=2)
        self.act_4 = nn.ReLU()

        self.layer_5 = nn.Conv2d(in_channels=128,out_channels=128,kernel_size=3,
                                 stride=1,padding=2)
        self.act_5 = nn.ReLU()
        
        self.max_1=nn.MaxPool2d(2,2)
        
        self.layer_6 = nn.Conv2d(in_channels=128,out_channels=256,kernel_size=3,
                                 stride=1,padding=2)
        self.act_6 = nn.ReLU()
        
        self.layer_7 = nn.Conv2d(in_channels=256,out_channels=256,kernel_size=3,
                                 stride=1,padding=2)
        self.act_7 = nn.ReLU()
        
        self.max_2=nn.MaxPool2d(2,2)
        
        self.layer_8 = nn.Conv2d(in_channels=256,out_channels=256,kernel_size=1,
                                 stride=1)
        self.act_8 = nn.ReLU()
        
        self.layer_9 = nn.Conv2d(in_channels=256,out_channels=256,kernel_size=3,
                                 stride=1,padding=2)
        self.act_9 = nn.ReLU()
        
        self.layer_10 = nn.Conv2d(in_channels=256,out_channels=256,kernel_size=3,
                                 stride=1,padding=2)
        self.act_10 = nn.ReLU()
        

        
        self.fc_layer_1 = nn.Linear(225*256,1000)
        self.act_11 = nn.ReLU()
        
        self.bnm1=nn.BatchNorm1d(1000)
        
        self.fc_layer_2 = nn.Linear(1000,10)
        self.act_12 = nn.ReLU()

        
        
        

    def forward(self, x):
        x = x.view(1,1,28,28)
        out = self.layer_1(x)
        out = self.act_1(out)
        for module in list(self.modules())[2:-5]:
            out = module(out)
        out = out.view(1,-1)
        for module in list(self.modules())[-5:]:
            out = module(out)
        return out

# %%
model=nn.DataParallel(Model().cuda())
model = torch.load("model_ver-1.07_All_dat")
model.eval()
# Out:
# /home/jupyter-vr/.local/lib/python3.7/site-packages/torch/serialization.py:649: SourceChangeWarning: source code of class 'torch.nn.parallel.data_parallel.DataParallel' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /home/jupyter-vr/.local/lib/python3.7/site-packages/torch/serialization.py:649: SourceChangeWarning: source code of class 'torch.nn.modules.conv.Conv2d' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /home/jupyter-vr/.local/lib/python3.7/site-packages/torch/serialization.py:649: SourceChangeWarning: source code of class 'torch.nn.modules.activation.ReLU' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /home/jupyter-vr/.local/lib/python3.7/site-packages/torch/serialization.py:649: SourceChangeWarning: source code of class 'torch.nn.modules.pooling.MaxPool2d' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /home/jupyter-vr/.local/lib/python3.7/site-packages/torch/serialization.py:649: SourceChangeWarning: source code of class 'torch.nn.modules.linear.Linear' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /home/jupyter-vr/.local/lib/python3.7/site-packages/torch/serialization.py:649: SourceChangeWarning: source code of class 'torch.nn.modules.batchnorm.BatchNorm1d' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# DataParallel(
#   (module): Model(
#     (layer_1): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (act_1): ReLU()
#     (layer_2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (act_2): ReLU()
#     (layer_3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (act_3): ReLU()
#     (layer_4): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (act_4): ReLU()
#     (layer_5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (act_5): ReLU()
#     (max_1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (layer_6): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (act_6): ReLU()
#     (layer_7): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (act_7): ReLU()
#     (max_2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (layer_8): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (act_8): ReLU()
#     (layer_9): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (act_9): ReLU()
#     (layer_10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (act_10): ReLU()
#     (fc_layer_1): Linear(in_features=57600, out_features=1000, bias=True)
#     (act_11): ReLU()
#     (bnm1): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (fc_layer_2): Linear(in_features=1000, out_features=10, bias=True)
#     (act_12): ReLU()
#   )
# )

# %%
save_output=np.zeros(20480)
for i in range (0,20480,4):
    output=model(torch.tensor(x_data[i:i+4]).cuda()).cpu().detach().numpy()
    output=output.reshape(4,10)
    save_output[i:i+4]=output.argmax(1)
# Out:
# ---------------------------------------------------------------------------
# ModuleAttributeError                      Traceback (most recent call last)
# <ipython-input-12-cbd01026b36d> in <module>
#       1 save_output=np.zeros(20480)
#       2 for i in range (0,20480,4):
# ----> 3     output=model(torch.tensor(x_data[i:i+4]).cuda()).cpu().detach().numpy()
#       4     output=output.reshape(4,10)
#       5     save_output[i:i+4]=output.argmax(1)
#
# ~/.local/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~/.local/lib/python3.7/site-packages/torch/nn/parallel/data_parallel.py in forward(self, *inputs, **kwargs)
#     152         if len(self.device_ids) == 1:
#     153             return self.module(*inputs[0], **kwargs[0])
# --> 154         replicas = self.replicate(self.module, self.device_ids[:len(inputs)])
#     155         outputs = self.parallel_apply(replicas, inputs, kwargs)
#     156         return self.gather(outputs, self.output_device)
#
# ~/.local/lib/python3.7/site-packages/torch/nn/parallel/data_parallel.py in replicate(self, module, device_ids)
#     157
#     158     def replicate(self, module, device_ids):
# --> 159         return replicate(module, device_ids, not torch.is_grad_enabled())
#     160
#     161     def scatter(self, inputs, kwargs, device_ids):
#
# ~/.local/lib/python3.7/site-packages/torch/nn/parallel/replicate.py in replicate(network, devices, detach)
#     131                 for j in range(num_replicas):
#     132                     replica = module_copies[j][i]
# --> 133                     setattr(replica, key, module_copies[j][module_idx])
#     134         for key, param in module._parameters.items():
#     135             if param is None:
#
# ~/.local/lib/python3.7/site-packages/torch/nn/modules/module.py in __setattr__(self, name, value)
#     800                     raise AttributeError(
#     801                         "cannot assign module before Module.__init__() call")
# --> 802                 remove_from(self.__dict__, self._parameters, self._buffers, self._non_persistent_buffers_set)
#     803                 modules[name] = value
#     804             elif modules is not None and name in modules:
#
# ~/.local/lib/python3.7/site-packages/torch/nn/modules/module.py in __getattr__(self, name)
#     770                 return modules[name]
#     771         raise ModuleAttributeError("'{}' object has no attribute '{}'".format(
# --> 772             type(self).__name__, name))
#     773
#     774     def __setattr__(self, name: str, value: Union[Tensor, 'Module']) -> None:
#
# ModuleAttributeError: 'Model' object has no attribute '_non_persistent_buffers_set'

# %%
save_output

# %%
save_output=save_output.astype(int)

# %%
test_id=np.arange(2049,2049+20480)

# %%
res=np.hstack((test_id.reshape(20480,1),
               save_output.reshape(20480,1)))

# %%
from pandas import Series, DataFrame

# %%
data_save=DataFrame(res, columns=['id','digit'])

# %%
data_save.to_csv("submit_data_1.07_3.csv",index = False)
